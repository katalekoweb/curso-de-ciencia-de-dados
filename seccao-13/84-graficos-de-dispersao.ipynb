# %%
# Formacao de cientista de dados
# Graficos de dispersao 
# usado para comparar duas variaveis numericas

# %%
# importcao das bibliotecas
import pandas as pd # tratamento de dados
import numpy as np #  biblioteca cientifica
import matplotlib.pyplot as plt
import seaborn as sns

# %%
base = pd.read_csv("trees.csv")
base.shape
# Out:
# (31, 3)

# %%
base.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
# grafico de dispersao
plt.scatter(x=base.Girth, y=base.Volume, color='blue', facecolors='none', marker='*')
plt.title('Arvores')
plt.xlabel("Circunferencia")
plt.ylabel("Volume")
# Out:
# Text(0, 0.5, 'Volume')

# %%
# grafico de linha considerando o volume e o atributo girth sem marker
plt.plot(base.Girth, base.Volume)
plt.title('Arvores')
plt.xlabel("Circunferencia")
plt.ylabel("Volume")
# Out:
# Text(0, 0.5, 'Volume')

# %%
# grafico de dispersao com seaborn com afastamento dos dados jitter
# fit_reg linha de tendencia
sns.regplot(x=base.Girth, y=base.Volume, data=base, x_jitter=0.3, fit_reg=False)
# Out:
# <Axes: xlabel='Girth', ylabel='Volume'>
